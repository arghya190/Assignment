# %% [markdown]
# <a href="https://colab.research.google.com/github/arghya190/Assignment/blob/main/Assignment_of_VAEs_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First, import the necessary packages.

# %%
#Import the libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Layer, Conv2D, Flatten, Dense, Reshape, Conv2DTranspose
import matplotlib.pyplot as plt

# %% [markdown]
# In VAEs, the sampling layer uses the output from two dense layers, z_mean and z_log_var, as inputs, followed by converting them into the normal distribution and passing them to the decoder layer.

# %%
#Sampling layer
class Sampling(Layer):

	def call(self, inputs):
		z_mean, z_log_var = inputs
		batch = tf.shape(z_mean)[0]
		dim = tf.shape(z_mean)[1]
		epsilon = tf.keras.backend.random_normal(shape =(batch, dim))
		return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# Here, we are defining the architecture of the encoder part of this autoencoder, which takes images as input, followed by encoding their representation in the sampling layer.

# %%
# Define Encoder Model
latent_dim = 2

encoder_inputs = Input(shape =(28, 28, 1))
x = Conv2D(32, 3, activation ="relu", strides = 2, padding ="same")(encoder_inputs)
x = Conv2D(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Flatten()(x)
x = Dense(16, activation ="relu")(x)
z_mean = Dense(latent_dim, name ="z_mean")(x)
z_log_var = Dense(latent_dim, name ="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name ="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)             18496     ['conv2d[0][0]']
#
#  flatten (Flatten)           (None, 3136)                 0         ['conv2d_1[0][0]']
#
#  dense (Dense)               (None, 16)                   50192     ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 2)                    34        ['dense[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    34        ['dense[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69076 (269.83 KB)
# Trainable params: 69076 (269.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# In this step, we are defining the architecture of the decoder part of the autoencoder, where the output of the sampling layer is given as input and produces an output image of size (28, 28, 1) .

# %%
# Define Decoder Architecture
latent_inputs = keras.Input(shape =(latent_dim, ))
x = Dense(7 * 7 * 64, activation ="relu")(latent_inputs)
x = Reshape((7, 7, 64))(x)
x = Conv2DTranspose(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Conv2DTranspose(32, 3, activation ="relu", strides = 2, padding ="same")(x)
decoder_outputs = Conv2DTranspose(1, 3, activation ="sigmoid", padding ="same")(x)
decoder = Model(latent_inputs, decoder_outputs, name ="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# In this step, we are defining the complete variational autoencoder architecture, followed by defining the training procedure with loss functions.

# %%
#Define the complete variational autoencoder architecture
class VAE(keras.Model):
	def __init__(self, encoder, decoder, **kwargs):
		super(VAE, self).__init__(**kwargs)
		self.encoder = encoder
		self.decoder = decoder

	def train_step(self, data):
		if isinstance(data, tuple):
			data = data[0]
		with tf.GradientTape() as tape:
			z_mean, z_log_var, z = encoder(data)
			reconstruction = decoder(z)
			reconstruction_loss = tf.reduce_mean(
				keras.losses.binary_crossentropy(data, reconstruction)
			)
			reconstruction_loss *= 28 * 28
			kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
			kl_loss = tf.reduce_mean(kl_loss)
			kl_loss *= -0.5
			total_loss = reconstruction_loss + kl_loss
		grads = tape.gradient(total_loss, self.trainable_weights)
		self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
		return {
			"loss": total_loss,
			"reconstruction_loss": reconstruction_loss,
			"kl_loss": kl_loss,
		}

# %% [markdown]
# Here, we shall train the variational autoencoder model for 50 epochs after importing the fashion MNIST dataset.

# %%
#Load the fashion mnist dataset
(x_train, _), (x_test, _) = keras.datasets.fashion_mnist.load_data()
fmnist_images = np.concatenate([x_train, x_test], axis = 0)
#Expansion of dimension for adding a color map dimension
fmnist_images = np.expand_dims(fmnist_images, -1).astype("float32") / 255

#Compile and train the VAE model
vae = VAE(encoder, decoder)
vae.compile(optimizer ='rmsprop')
vae.fit(fmnist_images, epochs = 50, batch_size = 64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1094/1094 [==============================] - 19s 7ms/step - loss: 318.3375 - reconstruction_loss: 312.9306 - kl_loss: 5.4069
# Epoch 2/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 280.1994 - reconstruction_loss: 275.2390 - kl_loss: 4.9604
# Epoch 3/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 274.4815 - reconstruction_loss: 269.9216 - kl_loss: 4.5599
# Epoch 4/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 271.3115 - reconstruction_loss: 266.9545 - kl_loss: 4.3570
# Epoch 5/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 268.9923 - reconstruction_loss: 264.8276 - kl_loss: 4.1647
# Epoch 6/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 266.7844 - reconstruction_loss: 262.8729 - kl_loss: 3.9114
# Epoch 7/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 265.2397 - reconstruction_loss: 261.4368 - kl_loss: 3.8029
# Epoch 8/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 264.0365 - reconstruction_loss: 260.2618 - kl_loss: 3.7747
# Epoch 9/50
# 1094/1094 [==============================] - 8s 8ms/step - loss: 263.1312 - reconstruction_loss: 259.3702 - kl_loss: 3.7610
# Epoch 10/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 262.4082 - reconstruction_loss: 258.6448 - kl_loss: 3.7633
# Epoch 11/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 261.7949 - reconstruction_loss: 258.0396 - kl_loss: 3.7553
# Epoch 12/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 261.1977 - reconstruction_loss: 257.4323 - kl_loss: 3.7653
# Epoch 13/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 260.7249 - reconstruction_loss: 256.9664 - kl_loss: 3.7585
# Epoch 14/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 260.2657 - reconstruction_loss: 256.5068 - kl_loss: 3.7589
# Epoch 15/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 259.9079 - reconstruction_loss: 256.1324 - kl_loss: 3.7755
# Epoch 16/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 259.5512 - reconstruction_loss: 255.7732 - kl_loss: 3.7780
# Epoch 17/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 259.2296 - reconstruction_loss: 255.4304 - kl_loss: 3.7993
# Epoch 18/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 258.8911 - reconstruction_loss: 255.0924 - kl_loss: 3.7987
# Epoch 19/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 258.6905 - reconstruction_loss: 254.8931 - kl_loss: 3.7973
# Epoch 20/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 258.4383 - reconstruction_loss: 254.6177 - kl_loss: 3.8206
# Epoch 21/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 258.2243 - reconstruction_loss: 254.4100 - kl_loss: 3.8143
# Epoch 22/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 257.9782 - reconstruction_loss: 254.1520 - kl_loss: 3.8263
# Epoch 23/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 257.7471 - reconstruction_loss: 253.9236 - kl_loss: 3.8235
# Epoch 24/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 257.5729 - reconstruction_loss: 253.7457 - kl_loss: 3.8272
# Epoch 25/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 257.3908 - reconstruction_loss: 253.5488 - kl_loss: 3.8420
# Epoch 26/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 257.1965 - reconstruction_loss: 253.3449 - kl_loss: 3.8516
# Epoch 27/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 257.0481 - reconstruction_loss: 253.1984 - kl_loss: 3.8497
# Epoch 28/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 256.9224 - reconstruction_loss: 253.0677 - kl_loss: 3.8547
# Epoch 29/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 256.7771 - reconstruction_loss: 252.9221 - kl_loss: 3.8550
# Epoch 30/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 256.6535 - reconstruction_loss: 252.8056 - kl_loss: 3.8480
# Epoch 31/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 256.5209 - reconstruction_loss: 252.6719 - kl_loss: 3.8490
# Epoch 32/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 256.4524 - reconstruction_loss: 252.5928 - kl_loss: 3.8596
# Epoch 33/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 256.3333 - reconstruction_loss: 252.4701 - kl_loss: 3.8631
# Epoch 34/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 256.2423 - reconstruction_loss: 252.3780 - kl_loss: 3.8643
# Epoch 35/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 256.1017 - reconstruction_loss: 252.2488 - kl_loss: 3.8528
# Epoch 36/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 256.0190 - reconstruction_loss: 252.1585 - kl_loss: 3.8606
# Epoch 37/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.9435 - reconstruction_loss: 252.0794 - kl_loss: 3.8641
# Epoch 38/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.8542 - reconstruction_loss: 251.9862 - kl_loss: 3.8680
# Epoch 39/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.7678 - reconstruction_loss: 251.8957 - kl_loss: 3.8722
# Epoch 40/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.6688 - reconstruction_loss: 251.7988 - kl_loss: 3.8700
# Epoch 41/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.5821 - reconstruction_loss: 251.7141 - kl_loss: 3.8680
# Epoch 42/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.5687 - reconstruction_loss: 251.6884 - kl_loss: 3.8803
# Epoch 43/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.4895 - reconstruction_loss: 251.6053 - kl_loss: 3.8842
# Epoch 44/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.4005 - reconstruction_loss: 251.5211 - kl_loss: 3.8793
# Epoch 45/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.3264 - reconstruction_loss: 251.4424 - kl_loss: 3.8840
# Epoch 46/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.2902 - reconstruction_loss: 251.4107 - kl_loss: 3.8795
# Epoch 47/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.2078 - reconstruction_loss: 251.3337 - kl_loss: 3.8741
# Epoch 48/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 255.1721 - reconstruction_loss: 251.2932 - kl_loss: 3.8789
# Epoch 49/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 255.0791 - reconstruction_loss: 251.1899 - kl_loss: 3.8892
# Epoch 50/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 255.0124 - reconstruction_loss: 251.1239 - kl_loss: 3.8885

# %% [markdown]
# Here we are displaying training results according to their latent space vectors.

# %%
def plot_latent(encoder, decoder):
	n = 9
	img_dim = 28
	scale = 2.0
	figsize = 15
	figure = np.zeros((img_dim * n, img_dim * n))

	grid_x = np.linspace(-scale, scale, n)
	grid_y = np.linspace(-scale, scale, n)[::-1]

	for i, yi in enumerate(grid_y):
		for j, xi in enumerate(grid_x):
			z_sample = np.array([[xi, yi]])
			x_decoded = decoder.predict(z_sample)
			images = x_decoded[0].reshape(img_dim, img_dim)
			figure[
				i * img_dim : (i + 1) * img_dim,
				j * img_dim : (j + 1) * img_dim,
			] = images

	plt.figure(figsize =(figsize, figsize))
	start_range = img_dim // 2
	end_range = n * img_dim + start_range + 1
	pixel_range = np.arange(start_range, end_range, img_dim)
	sample_range_x = np.round(grid_x, 1)
	sample_range_y = np.round(grid_y, 1)
	#plt.xticks(pixel_range, sample_range_x)
	#plt.yticks(pixel_range, sample_range_y)
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.imshow(figure, cmap ="Greys_r")
	plt.show()


plot_latent(encoder, decoder)
# Out:
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# The scatter plot of the training data generated from the encoder has been generated to get a clear idea of the latent vector values.

# %%
def plot_label_clusters(encoder, decoder, data, test_lab):
	z_mean, _, _ = encoder.predict(data)
	plt.figure(figsize =(12, 10))
	sc = plt.scatter(z_mean[:, 0], z_mean[:, 1], c = test_lab)
	cbar = plt.colorbar(sc, ticks = range(10))
	cbar.ax.set_yticklabels([labels.get(i) for i in range(10)])
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.show()


labels = {0 :"T-shirt / top",
1: "Trouser",
2: "Pullover",
3: "Dress",
4: "Coat",
5: "Sandal",
6: "Shirt",
7: "Sneaker",
8: "Bag",
9: "Ankle boot"}

(x_train, y_train), _ = keras.datasets.fashion_mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
plot_label_clusters(encoder, decoder, x_train, y_train)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step
